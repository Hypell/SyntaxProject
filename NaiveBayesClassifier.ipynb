# %%
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package bcp47 to /root/nltk_data...
# ...

# %%
from nltk.tokenize import word_tokenize

# %%
import pandas as pd
import os
os.getcwd()
# Out:
# '/content/drive/MyDrive/syntax_project'

# %%
os.chdir('/content/drive/My Drive/syntax_project')
training_source = pd.read_excel('training_source.xlsx')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-037a1db5de73> in <cell line: 1>()
# ----> 1 os.chdir('/content/drive/My Drive/syntax_project')
#       2 training_source = pd.read_excel('training_source.xlsx')
#
# NameError: name 'os' is not defined

# %%
training_source_num = len(training_source)

# %%
training_set = []

for i in range(0, training_source_num):
    training_set_1 = (training_source['초'].iloc[i], '초')
    training_set.append(training_set_1)
    training_set_2 = (training_source['중'].iloc[i], '중')
    training_set.append(training_set_2)
    training_set_3 = (training_source['고'].iloc[i], '고')
    training_set.append(training_set_3)

print(training_set)
# Out:
# [('Kate is from London.', '초'), ('The water in this river is clean. ', '중'), ('The audience is/are enjoying the show. ', '고'), ('A boy ran in the park.', '초'), ('She lived in the woods when she was a kid. ', '중'), ('The news is very interesting. ', '고'), ('Water is very important for life.', '초'), ('A lot of houses are made of wood. ', '중'), ('Germans are good musicians.', '고'), ('The store is closed.', '초'), ('Thank you for your kindness. ', '중'), ('I myself took this picture. ', '고'), ('This book is very interesting.', '초'), ('He does a kindness to poor people. ', '중'), ('I’d like to write a diary, but I’m too busy to do so.', '고'), ('That dog is smart.', '초'), ('Mathematics is my favorite subject. ', '중'), ('The monkey has been raised by human parents for years. ', '고'), ('Those books are really large.', '초'), ('You can choose any color you like. ', '중'), ('I was made to clean the room. ', '고'), ("We didn't buy much food.", '초'), ('Most good comedians tell some bad jokes. ', '중'),
# ...

# %%
all_words = set(word.lower() for sentence in training_set
                   for word in word_tokenize(sentence[0]))
all_words
# Out:
# {'(',
#  ')',
#  ',',
#  '.',
#  '?',
#  'a',
#  'about',
#  'accident',
#  'admires',
#  'all',
#  'amount',
#  'an',
#  'and',
#  'animals',
#  'any',
#  'apples',
#  'are',
#  'astronaut',
#  'at',
#  'audience',
#  'baby',
#  'bad',
#  'bananas',
#  'be',
#  'becoming',
#  'been',
#  'better',
#  'black',
#  'book',
#  'books',
#  'borrow',
#  'boy',
#  'brave',
#  'brown',
#  'building',
#  'busy',
#  'but',
#  'buy',
#  'by',
#  'came',
#  'can',
#  'children',
#  'choose',
#  'class',
#  'clean',
#  'closed',
#  'coat',
#  'color',
#  'comedians',
#  'd',
#  'defeated',
#  'delicious',
#  'diary',
#  'did',
#  'didn',
#  'do',
#  'does',
#  'doesn',
#  'dog',
#  'done',
#  'dream',
#  'each',
#  'energy',
#  'enjoying',
#  'enter',
#  'every',
#  'fact',
#  'favorite',
#  'few',
#  'food',
#  'for',
#  'from',
#  'german',
#  'germans',
#  'glad',
#  'glasses',
#  'good',
#  'great',
#  'had',
#  'has',
#  'have',
#  'he',
#  'hear',
#  'help',
#  'her',
#  'him',
# ...

# %%
all_words = []
for sentence in training_set:
    for word in word_tokenize(sentence[0]):
        all_words.append(word.lower())

set(all_words)
# Out:
# {'(',
#  ')',
#  ',',
#  '.',
#  '?',
#  'a',
#  'about',
#  'accident',
#  'admires',
#  'all',
#  'amount',
#  'an',
#  'and',
#  'animals',
#  'any',
#  'apples',
#  'are',
#  'astronaut',
#  'at',
#  'audience',
#  'baby',
#  'bad',
#  'bananas',
#  'be',
#  'becoming',
#  'been',
#  'better',
#  'black',
#  'book',
#  'books',
#  'borrow',
#  'boy',
#  'brave',
#  'brown',
#  'building',
#  'busy',
#  'but',
#  'buy',
#  'by',
#  'came',
#  'can',
#  'children',
#  'choose',
#  'class',
#  'clean',
#  'closed',
#  'coat',
#  'color',
#  'comedians',
#  'd',
#  'defeated',
#  'delicious',
#  'diary',
#  'did',
#  'didn',
#  'do',
#  'does',
#  'doesn',
#  'dog',
#  'done',
#  'dream',
#  'each',
#  'energy',
#  'enjoying',
#  'enter',
#  'every',
#  'fact',
#  'favorite',
#  'few',
#  'food',
#  'for',
#  'from',
#  'german',
#  'germans',
#  'glad',
#  'glasses',
#  'good',
#  'great',
#  'had',
#  'has',
#  'have',
#  'he',
#  'hear',
#  'help',
#  'her',
#  'him',
# ...

# %%
t = [({word: (word in word_tokenize(x[0]))
   for word in all_words}, x[1]) for x in training_set]
t
# Out:
# [({'kate': False,
#    'is': True,
#    'from': True,
#    'london': False,
#    '.': True,
#    'the': False,
#    'water': False,
#    'in': False,
#    'this': False,
#    'river': False,
#    'clean': False,
#    'audience': False,
#    'is/are': False,
#    'enjoying': False,
#    'show': False,
#    'a': False,
#    'boy': False,
#    'ran': False,
#    'park': False,
#    'she': False,
#    'lived': False,
#    'woods': False,
#    'when': False,
#    'was': False,
#    'kid': False,
#    'news': False,
#    'very': False,
#    'interesting': False,
#    'important': False,
#    'for': False,
#    'life': False,
#    'lot': False,
#    'of': False,
#    'houses': False,
#    'are': False,
#    'made': False,
#    'wood': False,
#    'germans': False,
#    'good': False,
#    'musicians': False,
#    'store': False,
#    'closed': False,
#    'thank': False,
#    'you': False,
#    'your': False,
#    'kindness': False,
#    'i': False,
#    'myself': False,
# ...

# %%
classifier = nltk.NaiveBayesClassifier.train(t)
classifier.show_most_informative_features()
# Out:
# Most Informative Features
#                      the = True                고 : 초      =      4.3 : 1.0
#                       to = True                고 : 초      =      3.7 : 1.0
#                      was = True                고 : 중      =      3.7 : 1.0
#                        , = True                고 : 중      =      3.0 : 1.0
#                        a = True                고 : 초      =      3.0 : 1.0
#                       is = True                초 : 고      =      2.6 : 1.0
#                      are = True                중 : 고      =      2.3 : 1.0
#                     good = True                중 : 고      =      2.3 : 1.0
#                       in = True                중 : 초      =      2.3 : 1.0
#                     like = True                초 : 고      =      2.3 : 1.0

# %%
test_sentence = 'He came not to complain, but to help us. '

test_sent_features = {word.lower() : (word in word_tokenize(test_sentence.lower()))
                                         for word in all_words}
test_sent_features
# Out:
# {'kate': False,
#  'is': False,
#  'from': False,
#  'london': False,
#  '.': True,
#  'the': False,
#  'water': False,
#  'in': False,
#  'this': False,
#  'river': False,
#  'clean': False,
#  'audience': False,
#  'is/are': False,
#  'enjoying': False,
#  'show': False,
#  'a': False,
#  'boy': False,
#  'ran': False,
#  'park': False,
#  'she': False,
#  'lived': False,
#  'woods': False,
#  'when': False,
#  'was': False,
#  'kid': False,
#  'news': False,
#  'very': False,
#  'interesting': False,
#  'important': False,
#  'for': False,
#  'life': False,
#  'lot': False,
#  'of': False,
#  'houses': False,
#  'are': False,
#  'made': False,
#  'wood': False,
#  'germans': False,
#  'good': False,
#  'musicians': False,
#  'store': False,
#  'closed': False,
#  'thank': False,
#  'you': False,
#  'your': False,
#  'kindness': False,
#  'i': False,
#  'myself': False,
#  'took': False,
#  'picture': False,
#  'book': False,
#  'he': True,
#  'does': False,
#  'to': True,
# ...

# %%
classifier.classify(test_sent_features)
# Out:
# '초'
